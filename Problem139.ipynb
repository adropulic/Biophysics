# %%
import numpy as np
import matplotlib.pyplot as plt
import math as math 
from scipy.optimize import curve_fit

# %%
tau = np.linspace(1,100,100)
R_info = (1/(2*tau))*np.log2(1+tau)
plt.plot(tau, R_info)
plt.xlabel('tau')
plt.ylabel('$R_{info}$')
# Out:
# Text(0,0.5,'$R_{info}$')

# %% [markdown]
# It appears that $\tau = 0$ maximizes the information rate, which is not consistent with the assumption that $\tau >> \tau_{0}$? But, it makes sense that you'd get the most information in the instant that you look at an object.
